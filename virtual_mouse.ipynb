# %%
pip install opencv-python mediapipe pyautogui
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.13.0.92)
# Collecting mediapipe
#   Using cached mediapipe-0.10.35-py3-none-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: pyautogui in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.9.54)
# Requirement already satisfied: numpy>=2 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from opencv-python) (2.4.6)
# Requirement already satisfied: absl-py~=2.3 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (2.4.0)
# Requirement already satisfied: certifi in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (2026.6.17)
# Requirement already satisfied: sounddevice~=0.5 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (0.5.5)
# Requirement already satisfied: flatbuffers~=25.9 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (25.12.19)
# Requirement already satisfied: opencv-contrib-python in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (4.13.0.92)
# Requirement already satisfied: matplotlib in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe) (3.11.0)
# Requirement already satisfied: pymsgbox in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyautogui) (2.0.1)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyautogui) (1.0.1)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: cffi in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sounddevice~=0.5->mediapipe) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pyperclip in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mouseinfo->pyautogui) (1.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi->sounddevice~=0.5->mediapipe) (3.0)
# Using cached mediapipe-0.10.35-py3-none-win_amd64.whl (10.9 MB)
# Installing collected packages: mediapipe
# Successfully installed mediapipe-0.10.35
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\a\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Index finger tip = landmark[8]
#
# ## Thumb tip = landmark[4]
#
# ## Middle finger tip = landmark[12]

# %%
import cv2
import mediapipe as mp
import pyautogui
import numpy as np
import time

# Setup
cap = cv2.VideoCapture(0)
screen_width, screen_height = pyautogui.size()
mpHands = mp.solutions.hands
hands = mpHands.Hands(max_num_hands=1)
mpDraw = mp.solutions.drawing_utils

# Smoothening
prev_x, prev_y = 0, 0
smoothening = 7

while True:
    success, img = cap.read()
    img = cv2.flip(img, 1)  # Mirror the image
    h, w, _ = img.shape
    rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    result = hands.process(rgb_img)
    if result.multi_hand_landmarks:
        for handLms in result.multi_hand_landmarks:
            lmList = []
            for id, lm in enumerate(handLms.landmark):
                lmList.append(lm)
                cx, cy = int(lm.x * w), int(lm.y * h)
                cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)

            # Index tip (8), Thumb tip (4)
            x1 = int(lmList[8].x * screen_width)
            y1 = int(lmList[8].y * screen_height)

            x2 = int(lmList[4].x * w)
            y2 = int(lmList[4].y * h)

            # Move cursor
            curr_x = prev_x + (x1 - prev_x) / smoothening
            curr_y = prev_y + (y1 - prev_y) / smoothening
            pyautogui.moveTo(curr_x, curr_y)
            prev_x, prev_y = curr_x, curr_y

            # Check for click
            distance = np.hypot(x2 - int(lmList[8].x * w), y2 - int(lmList[8].y * h))
            if distance < 30:
                pyautogui.click()
                time.sleep(0.2)  # Debounce delay

            mpDraw.draw_landmarks(img, handLms, mpHands.HAND_CONNECTIONS)

    cv2.imshow("Virtual Mouse", img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\a\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '

# %%
# %pip install mediapipe==0.10.14
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mediapipe==0.10.14
#   Downloading mediapipe-0.10.14-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: absl-py in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe==0.10.14) (2.4.0)
# Collecting attrs>=19.1.0 (from mediapipe==0.10.14)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe==0.10.14) (25.12.19)
# Collecting jax (from mediapipe==0.10.14)
#   Downloading jax-0.10.2-py3-none-any.whl.metadata (13 kB)
# Collecting jaxlib (from mediapipe==0.10.14)
#   Downloading jaxlib-0.10.2-cp312-cp312-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: matplotlib in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe==0.10.14) (3.11.0)
# Requirement already satisfied: numpy in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe==0.10.14) (2.4.6)
# Requirement already satisfied: opencv-contrib-python in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe==0.10.14) (4.13.0.92)
# Collecting protobuf<5,>=4.25.3 (from mediapipe==0.10.14)
#   Using cached protobuf-4.25.9-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from mediapipe==0.10.14) (0.5.5)
# Requirement already satisfied: cffi in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sounddevice>=0.4.4->mediapipe==0.10.14) (2.0.0)
# Collecting ml_dtypes>=0.5.0 (from jax->mediapipe==0.10.14)
#   Using cached ml_dtypes-0.5.4-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting opt_einsum (from jax->mediapipe==0.10.14)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting scipy>=1.14 (from jax->mediapipe==0.10.14)
#   Downloading scipy-1.18.0-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe==0.10.14) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe==0.10.14) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe==0.10.14) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe==0.10.14) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe==0.10.14) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe==0.10.14) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe==0.10.14) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->mediapipe==0.10.14) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.14) (1.17.0)
# Requirement already satisfied: pycparser in c:\users\a\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from cffi->sounddevice>=0.4.4->mediapipe==0.10.14) (3.0)
# Downloading mediapipe-0.10.14-cp312-cp312-win_amd64.whl (50.8 MB)
#    ---------------------------------------- 0.0/50.8 MB ? eta -:--:--
#    --------- ------------------------------ 12.3/50.8 MB 64.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 22.8/50.8 MB 55.5 MB/s eta 0:00:01
#    ------------------- -------------------- 24.9/50.8 MB 40.4 MB/s eta 0:00:01
#    -------------------- ------------------- 26.5/50.8 MB 31.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 28.3/50.8 MB 27.2 MB/s eta 0:00:01
#    ------------------------ --------------- 30.9/50.8 MB 24.5 MB/s eta 0:00:01
#    --------------------------- ------------ 34.6/50.8 MB 23.4 MB/s eta 0:00:01
#    ------------------------------- -------- 39.6/50.8 MB 23.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 45.4/50.8 MB 24.0 MB/s eta 0:00:01
#    ---------------------------------------  50.6/50.8 MB 24.8 MB/s eta 0:00:01
#    ---------------------------------------  50.6/50.8 MB 24.8 MB/s eta 0:00:01
#    ---------------------------------------- 50.8/50.8 MB 21.6 MB/s eta 0:00:00
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Using cached protobuf-4.25.9-cp310-abi3-win_amd64.whl (413 kB)
# Downloading jax-0.10.2-py3-none-any.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ---------------------------------------- 3.2/3.2 MB 21.1 MB/s eta 0:00:00
# Downloading jaxlib-0.10.2-cp312-cp312-win_amd64.whl (65.9 MB)
#    ---------------------------------------- 0.0/65.9 MB ? eta -:--:--
#    --- ------------------------------------ 6.3/65.9 MB 32.2 MB/s eta 0:00:02
#    ------ --------------------------------- 11.3/65.9 MB 27.1 MB/s eta 0:00:03
#    --------- ------------------------------ 15.5/65.9 MB 24.3 MB/s eta 0:00:03
#    ------------ --------------------------- 20.4/65.9 MB 24.4 MB/s eta 0:00:02
#    -------------- ------------------------- 24.6/65.9 MB 23.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 28.6/65.9 MB 22.6 MB/s eta 0:00:02
#    ------------------- -------------------- 32.5/65.9 MB 21.9 MB/s eta 0:00:02
#    --------------------- ------------------ 35.9/65.9 MB 21.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 38.8/65.9 MB 20.4 MB/s eta 0:00:02
#    --------------------------- ------------ 44.8/65.9 MB 21.1 MB/s eta 0:00:01
#    ------------------------------- -------- 52.4/65.9 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------ --- 60.3/65.9 MB 23.7 MB/s eta 0:00:01
#    ---------------------------------------  65.3/65.9 MB 23.9 MB/s eta 0:00:01
#    ---------------------------------------  65.8/65.9 MB 23.8 MB/s eta 0:00:01
#    ---------------------------------------- 65.9/65.9 MB 21.0 MB/s eta 0:00:00
# Using cached ml_dtypes-0.5.4-cp312-cp312-win_amd64.whl (212 kB)
# Downloading scipy-1.18.0-cp312-cp312-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ------- -------------------------------- 7.1/36.6 MB 33.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 14.7/36.6 MB 35.5 MB/s eta 0:00:01
#    ------------------------- -------------- 23.1/36.6 MB 36.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 27.0/36.6 MB 32.3 MB/s eta 0:00:01
#    --------------------------------- ------ 30.4/36.6 MB 29.2 MB/s eta 0:00:01
#    -------------------------------------- - 34.9/36.6 MB 27.7 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.6 MB 27.2 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 23.3 MB/s eta 0:00:00
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Installing collected packages: scipy, protobuf, opt_einsum, ml_dtypes, attrs, jaxlib, jax, mediapipe
#   Attempting uninstall: mediapipe
#     Found existing installation: mediapipe 0.10.35
#     Uninstalling mediapipe-0.10.35:
#       Successfully uninstalled mediapipe-0.10.35
# Successfully installed attrs-26.1.0 jax-0.10.2 jaxlib-0.10.2 mediapipe-0.10.14 ml_dtypes-0.5.4 opt_einsum-3.4.0 protobuf-4.25.9 scipy-1.18.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\a\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
